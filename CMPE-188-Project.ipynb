# %%
import pandas 
import matplotlib.pyplot as plt
import nltk
from sklearn.decomposition import PCA
from nltk.corpus import stopwords
from sklearn import datasets
from sklearn import naive_bayes
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
import numpy as np
import json
import codecs
import numpy


with codecs.open("/Users/erickmena/Desktop/trump_subdataset.json", "r", "utf-8") as json_data:
    data = json.load(json_data)
print(len(data))

y = np.array([])

print("----------------")
for item in data:
    print(item["class"])
    y = numpy.append(y, [item["class"]])

print("----------------")


print( "Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(strip_accents= "ascii", \
                             analyzer     = "word",  \
                         #    ngram_range  = (3,12) , \
                             tokenizer    = None,    \
                             preprocessor = None,    \
                             stop_words   = None,    \
                             max_features = 5000,    \
                         #    stop_words   = "engilsh",\
                             lowercase    = True   \
                            ) 

joinedTweets = list()
for item in data:
    # print(item)
    joinedTweets.append(" ".join(item["tweets"]))

train_data_features = vectorizer.fit_transform(joinedTweets)

train_data_features = train_data_features.toarray()


clf = GaussianNB()
clf.fit(train_data_features, y)

print(clf)

clf_pf = GaussianNB()
clf_pf.partial_fit(train_data_features, y, np.unique(Y))

print(clf_pf)

# Split the data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(train_data_features, y, test_size=0.3, random_state=0)
gnb = GaussianNB()
mnb = MultinomialNB()
 
y_pred_gnb = gnb.fit(X_train, y_train).predict(X_test)
cnf_matrix_gnb = confusion_matrix(y_test, y_pred_gnb)
 
print(cnf_matrix_gnb)

y_pred_mnb = mnb.fit(X_train, y_train).predict(X_test)
cnf_matrix_mnb = confusion_matrix(y_test, y_pred_mnb)
 
print(cnf_matrix_mnb)
